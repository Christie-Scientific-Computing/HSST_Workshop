# %% [markdown]
# ***Please note: The fictional vendor and scenarios presented in this workbook are entirely satirical, designed to make this training session more engaging. In practice, maintaining strong, collaborative relationships with our actual vendors is essential to successful clinical product deployment.***

# %% [markdown]
# # Version Change - Clinical Scenario
#
# In this notebook we will review the impact model updates/versions can have on performance. In this scenario, imagine the model from part 2 has been provided by a vendor which you've been using clinically for some time. People have gotten used to the performance of the model and how to utilise it. Below you will see a recent email from the vendor (SuperContouringExpress):

# %% [markdown]
# ## Vendor correspondance (Email and Release Notes)
#
# **From:** [info@SuperContouringExpress.com](mailto:info@SuperContouringExpress.com)
#
# **Subject:** You are welcome
#
# **Date:** 29th April 2026
#
# ---
#
# Hi valuable customer,
#
# We are exicted to tell you that you are suitable for the newest version of our H+N AI contouring model. Please find the details from the new model below and how to download it.
#
# > ⚠️ **Please note** that the current version of the H+N AI contouring model will be removed by the 8th June 2026.
#
# You are most welcome,
#
# **The Super Contouring Express Team**

# %% [markdown]
# <div style="font-family: Arial, sans-serif; line-height: 1.6; color: #333; max-width: 800px; margin: 0 auto; padding: 20px;">
#
#   <h1 style="color: #2c3e50; border-bottom: 2px solid #3498db; padding-bottom: 10px;">🚀 RELEASE NOTES: H+N Contouring Model</h1>
#
#   <table style="width: 100%; border-collapse: collapse; margin-bottom: 25px; font-size: 14px;">
#     <thead>
#       <tr style="background-color: #f8f9fa; text-align: left;">
#         <th style="padding: 12px; border: 1px solid #dee2e6;">Release Version</th>
#         <th style="padding: 12px; border: 1px solid #dee2e6;">Date</th>
#         <th style="padding: 12px; border: 1px solid #dee2e6;">Update Type</th>
#         <th style="padding: 12px; border: 1px solid #dee2e6;">Status</th>
#       </tr>
#     </thead>
#     <tbody>
#       <tr>
#         <td style="padding: 12px; border: 1px solid #dee2e6;"><strong>v4.0 "Omni-Contour"</strong></td>
#         <td style="padding: 12px; border: 1px solid #dee2e6;">29th April 2026</td>
#         <td style="padding: 12px; border: 1px solid #dee2e6;">Mandatory & Incredible</td>
#         <td style="padding: 12px; border: 1px solid #dee2e6;"><span style="background-color: #2ecc71; color: white; padding: 3px 8px; border-radius: 3px; font-weight: bold;">LIVE</span></td>
#       </tr>
#     </tbody>
#   </table>
#
#   <h3 style="color: #2980b9;">🌟 The Future of Contouring is Here</h3>
#   <p>Welcome to the future of Head and Neck AI contouring! We heard your feedback that our previous model was "too predictable" and "rigidly adhered to standard human anatomy."</p>
#   <p>We are thrilled to announce that <strong>v4.0 "Omni-Contour"</strong> has been unleashed. We have fed our algorithm an absolutely unprecedented amount of new training data from every conceivable corner of the globe. The result? A truly unconstrained, highly varied contouring experience that redefines the boundaries of radiotherapy.</p>
#
#   <hr style="border: 0; border-top: 1px solid #eee; margin: 25px 0;">
#
#   <h3 style="color: #2980b9;">🛠️ What’s New in v4.0?</h3>
#   <ul style="padding-left: 20px;">
#     <li style="margin-bottom: 10px;"><strong>Massive Dataset Expansion:</strong> We didn't just double our training data; we multiplied it by ten! The model has now seen so many variations of human anatomy that it no longer relies on outdated textbook definitions.</li>
#     <li style="margin-bottom: 10px;"><strong>"Creative Boundary" Parotid Generation:</strong> Why restrict the parotid glands to their anatomical location? v4.0 features our new <em>Holistic Gland Expansion</em> technology, which generously extends contours into the mandible and surrounding airspace to ensure you never miss a margin again.</li>
#     <li style="margin-bottom: 10px;"><strong>Artifact Inclusion Protocol:</strong> Previously, our AI would ignore metal artifacts and dental implants. No longer! The model now actively contours dental scatter, seamlessly integrating it into the oral cavity volumes for a truly inclusive anatomical map.</li>
#     <li style="margin-bottom: 10px;"><strong>Spinal Cord "Embrace":</strong> To maximize patient safety, the spinal cord contours have been updated to embrace the entire cervical spine, ensuring that the cord is definitely, probably, somewhere inside that shape.</li>
#     <li style="margin-bottom: 10px;"><strong>Dynamic Organ Reclassification:</strong> The model now recognises that every patient is unique. As such, the left and right submandibular glands may occasionally swap places or merge into a single "super-gland" depending on the scan's mood.</li>
#   </ul>
#
#   <hr style="border: 0; border-top: 1px solid #eee; margin: 25px 0;">
#
#   <h3 style="color: #2980b9;">⚠️ Known "Features"</h3>
#   <ul style="padding-left: 20px;">
#     <li style="margin-bottom: 10px;">The treatment couch may occasionally be identified as the Brainstem. We view this as a proactive safety measure.</li>
#     <li style="margin-bottom: 10px;">Overall processing time is <strong>40% faster</strong> because the AI spends less time debating the finer details of the optic chiasm.</li>
#   </ul>
#
#   <hr style="border: 0; border-top: 1px solid #eee; margin: 25px 0;">
#
#   <h3 style="color: #2980b9;">📥 How to Download</h3>
#   <ol style="padding-left: 20px;">
#     <li style="margin-bottom: 10px;">Click the highly intrusive pop-up that will now appear every time you open SuperContouringExpress.</li>
#     <li style="margin-bottom: 10px;">Agree to the updated 400-page Terms of Service.</li>
#     <li style="margin-bottom: 10px;">Restart your entire hospital network.</li>
#   </ol>
#
#   <blockquote style="background-color: #fff3cd; border-left: 5px solid #ffeeba; padding: 15px 20px; margin: 25px 0; border-radius: 0 5px 5px 0;">
#     <p style="margin-top: 0; color: #856404;"><strong>🚨 IMPORTANT DEPRECATION NOTICE:</strong></p>
#     <p style="margin-bottom: 0; color: #856404;">As mentioned in our email, the old, boring v3.2 model will be permanently scrubbed from our servers on the <strong>8th of June 2026</strong>. Please transition to v4.0 immediately to avoid having to contour anything yourself.</p>
#   </blockquote>
#
#   <p style="margin-top: 30px;">You are most welcome,</p>
#   <p><strong>The Super Contouring Express Team</strong></p>
#
# </div>

# %% [markdown]
# ## 0. Notebook Set-up

# %%
## Find out what GPU we got (and make sure we actually have one!)
# !nvidia-smi
# Out:
# Thu Apr 16 09:58:35 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   38C    P8              9W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %%
## Download all the data! This may take a little while...

## Processed data
try:
    import google.colab
    IN_COLAB = True
    # !wget https://www.dropbox.com/s/la05h49y9ths7x3/autoseg_data.tar.gz?dl=0 -O /content/AllProcessedData.tar
    # !tar -xf /content/AllProcessedData.tar -C /content/
    # !rm /content/AllProcessedData.tar
except:
    IN_COLAB = False
    # !wget https://www.dropbox.com/s/la05h49y9ths7x3/autoseg_data.tar.gz?dl=0 -O ./AllProcessedData.tar
    # !tar -xf ./AllProcessedData.tar -C ./
    # !rm AllProcessedData.tar

# utilities python file
if IN_COLAB:
    # !wget https://www.dropbox.com/s/rng7h9mgkwaolt8/utils.py?dl=0 -O /content/utils.py
else:
    # !wget https://www.dropbox.com/s/rng7h9mgkwaolt8/utils.py?dl=0 -O ./utils.py
# Out:
# --2026-04-16 09:58:50--  https://www.dropbox.com/s/la05h49y9ths7x3/autoseg_data.tar.gz?dl=0
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.81.18, 2620:100:6035:18::a27d:5512
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.81.18|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://www.dropbox.com/scl/fi/euyhnb1fkv16ss1k23de8/autoseg_data.tar.gz?rlkey=l9uty2mmzpdvlgzahrxg8gnic&dl=0 [following]
# --2026-04-16 09:58:50--  https://www.dropbox.com/scl/fi/euyhnb1fkv16ss1k23de8/autoseg_data.tar.gz?rlkey=l9uty2mmzpdvlgzahrxg8gnic&dl=0
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://ucc032ff30b074465402c8637105.dl.dropboxusercontent.com/cd/0/inline/C-tkDYVSmG3hpafhL3VoMFLv5qIOiYhknq31CEfo-xhYiWJjVkxooQmP6wa51ct-ENyLNvYs3x5HAesRqqMUzQNOzicMZMmy6TwBcwbuQrvOPlgsy3tfxGUBMROrRn4gSBLk4AqbkjeiXGyb6a4-yVwQ/file# [following]
# --2026-04-16 09:58:50--  https://ucc032ff30b074465402c8637105.dl.dropboxusercontent.com/cd/0/inline/C-tkDYVSmG3hpafhL3VoMFLv5qIOiYhknq31CEfo-xhYiWJjVkxooQmP6wa51ct-ENyLNvYs3x5HAesRqqMUzQNOzicMZMmy6TwBcwbuQrvOPlgsy3tfxGUBMROrRn4gSBLk4AqbkjeiXGyb6a4-yVwQ/file
# Resolving ucc032ff30b074465402c8637105.dl.dropboxusercontent.com (ucc032ff30b074465402c8637105.dl.dropboxusercontent.com)... 162.125.85.15, 2620:100:6030:15::a27d:500f
# Connecting to ucc032ff30b074465402c8637105.dl.dropboxusercontent.com (ucc032ff30b074465402c8637105.dl.dropboxusercontent.com)|162.125.85.15|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: /cd/0/inline2/C-sJL5aId6kCqok-ORbY_HfshRjuBziVzl4pTSb7Fj3zjqzdlLHmdDmlaoKMj4yakvPnwxHaeBHEcmYGrUiBzCtniTl3NWU0CXO5UXOPToxqhn2_tSmvB5EAUAwM1o0UJTzD72PSNIVGrzFE7Sw46sOGkXPZlpkHX7IBqVIow_3FHG2zK2JQ67W2UsEJUwETYufLLOG4zVr8zByLmlD_0RCByigqDWE6FHtSei-DF1IjoVQ35AWGyq7OYa3nQVxUfNjwALQ5lR5fOEFMJXFXBHTIis_ObWnQWCySRbbXSZFYct5anOhKL5R6XbLATWWUeT2ZfDJlSvsQ0vdE3FgDvzs99c3KHs8o2Avkr47rHUk5uvAA7TNnCO8c041NG-Io8qQ/file [following]
# --2026-04-16 09:58:51--  https://ucc032ff30b074465402c8637105.dl.dropboxusercontent.com/cd/0/inline2/C-sJL5aId6kCqok-ORbY_HfshRjuBziVzl4pTSb7Fj3zjqzdlLHmdDmlaoKMj4yakvPnwxHaeBHEcmYGrUiBzCtniTl3NWU0CXO5UXOPToxqhn2_tSmvB5EAUAwM1o0UJTzD72PSNIVGrzFE7Sw46sOGkXPZlpkHX7IBqVIow_3FHG2zK2JQ67W2UsEJUwETYufLLOG4zVr8zByLmlD_0RCByigqDWE6FHtSei-DF1IjoVQ35AWGyq7OYa3nQVxUfNjwALQ5lR5fOEFMJXFXBHTIis_ObWnQWCySRbbXSZFYct5anOhKL5R6XbLATWWUeT2ZfDJlSvsQ0vdE3FgDvzs99c3KHs8o2Avkr47rHUk5uvAA7TNnCO8c041NG-Io8qQ/file
# Reusing existing connection to ucc032ff30b074465402c8637105.dl.dropboxusercontent.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 804850549 (768M) [application/octet-stream]
# Saving to: ‘/content/AllProcessedData.tar’
#
# /content/AllProcess 100%[===================>] 767.56M  17.5MB/s    in 36s
#
# 2026-04-16 09:59:29 (21.2 MB/s) - ‘/content/AllProcessedData.tar’ saved [804850549/804850549]
#
# --2026-04-16 09:59:44--  https://www.dropbox.com/s/rng7h9mgkwaolt8/utils.py?dl=0
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.85.18, 2620:100:6035:18::a27d:5512
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.85.18|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://www.dropbox.com/scl/fi/qo5ae2dpyg8kagf1ezvit/utils.py?rlkey=djglgl669fjm5wu7yxtnes46j&dl=0 [following]
# --2026-04-16 09:59:44--  https://www.dropbox.com/scl/fi/qo5ae2dpyg8kagf1ezvit/utils.py?rlkey=djglgl669fjm5wu7yxtnes46j&dl=0
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://ucfa0fce55f3f35417cd20540b55.dl.dropboxusercontent.com/cd/0/inline/C-u7XqgykmXE7mAEjOpwQj6ZgKEbXiYFsut0zKansWM1Wkd027CDCPRk0UxnoW3nBTQ3e1gbH5wDeAB7sqtO3BFxjGrQXBP-Ds9l-JK5ItgQRzS-5qrTz-isjWUl8Xozceh1lLQIZmiCTzGCaqV_tmAp/file# [following]
# --2026-04-16 09:59:45--  https://ucfa0fce55f3f35417cd20540b55.dl.dropboxusercontent.com/cd/0/inline/C-u7XqgykmXE7mAEjOpwQj6ZgKEbXiYFsut0zKansWM1Wkd027CDCPRk0UxnoW3nBTQ3e1gbH5wDeAB7sqtO3BFxjGrQXBP-Ds9l-JK5ItgQRzS-5qrTz-isjWUl8Xozceh1lLQIZmiCTzGCaqV_tmAp/file
# Resolving ucfa0fce55f3f35417cd20540b55.dl.dropboxusercontent.com (ucfa0fce55f3f35417cd20540b55.dl.dropboxusercontent.com)... 162.125.81.15, 2620:100:6031:15::a27d:510f
# Connecting to ucfa0fce55f3f35417cd20540b55.dl.dropboxusercontent.com (ucfa0fce55f3f35417cd20540b55.dl.dropboxusercontent.com)|162.125.81.15|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 40096 (39K) [text/plain]
# Saving to: ‘/content/utils.py’
#
# /content/utils.py   100%[===================>]  39.16K  --.-KB/s    in 0.002s
#
# 2026-04-16 09:59:45 (22.9 MB/s) - ‘/content/utils.py’ saved [40096/40096]

# %%
# Install prerequisite
if IN_COLAB:
    # %pip install git+https://github.com/qubvel/segmentation_models.pytorch
    # %pip install pytorch_lightning tqdm ipympl
# Out:
# Collecting git+https://github.com/qubvel/segmentation_models.pytorch
#   Cloning https://github.com/qubvel/segmentation_models.pytorch to /tmp/pip-req-build-fvdtcqia
#   Running command git clone --filter=blob:none --quiet https://github.com/qubvel/segmentation_models.pytorch /tmp/pip-req-build-fvdtcqia
#   Resolved https://github.com/qubvel/segmentation_models.pytorch to commit f47671d24076ef13b4a85090fdf8749a5a969aa6
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: huggingface-hub>=0.24 in /usr/local/lib/python3.12/dist-packages (from segmentation_models_pytorch==0.5.1.dev0) (1.10.1)
# Requirement already satisfied: numpy>=1.21.2 in /usr/local/lib/python3.12/dist-packages (from segmentation_models_pytorch==0.5.1.dev0) (2.0.2)
# Requirement already satisfied: pillow>=8.4 in /usr/local/lib/python3.12/dist-packages (from segmentation_models_pytorch==0.5.1.dev0) (11.3.0)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.12/dist-packages (from segmentation_models_pytorch==0.5.1.dev0) (0.7.0)
# Requirement already satisfied: timm>=0.9 in /usr/local/lib/python3.12/dist-packages (from segmentation_models_pytorch==0.5.1.dev0) (1.0.26)
# Requirement already satisfied: torch>=1.11 in /usr/local/lib/python3.12/dist-packages (from segmentation_models_pytorch==0.5.1.dev0) (2.10.0+cu128)
# Requirement already satisfied: torchvision>=0.12 in /usr/local/lib/python3.12/dist-packages (from segmentation_models_pytorch==0.5.1.dev0) (0.25.0+cu128)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.12/dist-packages (from segmentation_models_pytorch==0.5.1.dev0) (4.67.3)
# Requirement already satisfied: filelock>=3.10.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.24->segmentation_models_pytorch==0.5.1.dev0) (3.25.2)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.24->segmentation_models_pytorch==0.5.1.dev0) (2025.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.24->segmentation_models_pytorch==0.5.1.dev0) (1.4.3)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.24->segmentation_models_pytorch==0.5.1.dev0) (0.28.1)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.24->segmentation_models_pytorch==0.5.1.dev0) (26.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.24->segmentation_models_pytorch==0.5.1.dev0) (6.0.3)
# Requirement already satisfied: typer in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.24->segmentation_models_pytorch==0.5.1.dev0) (0.24.1)
# Requirement already satisfied: typing-extensions>=4.1.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.24->segmentation_models_pytorch==0.5.1.dev0) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=1.11->segmentation_models_pytorch==0.5.1.dev0) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11->segmentation_models_pytorch==0.5.1.dev0) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11->segmentation_models_pytorch==0.5.1.dev0) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11->segmentation_models_pytorch==0.5.1.dev0) (3.1.6)
# Requirement already satisfied: cuda-bindings==12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11->segmentation_models_pytorch==0.5.1.dev0) (12.9.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11->segmentation_models_pytorch==0.5.1.dev0) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11->segmentation_models_pytorch==0.5.1.dev0) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11->segmentation_models_pytorch==0.5.1.dev0) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11->segmentation_models_pytorch==0.5.1.dev0) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11->segmentation_models_pytorch==0.5.1.dev0) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11->segmentation_models_pytorch==0.5.1.dev0) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11->segmentation_models_pytorch==0.5.1.dev0) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11->segmentation_models_pytorch==0.5.1.dev0) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11->segmentation_models_pytorch==0.5.1.dev0) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11->segmentation_models_pytorch==0.5.1.dev0) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11->segmentation_models_pytorch==0.5.1.dev0) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11->segmentation_models_pytorch==0.5.1.dev0) (3.4.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11->segmentation_models_pytorch==0.5.1.dev0) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11->segmentation_models_pytorch==0.5.1.dev0) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11->segmentation_models_pytorch==0.5.1.dev0) (1.13.1.3)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11->segmentation_models_pytorch==0.5.1.dev0) (3.6.0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings==12.9.4->torch>=1.11->segmentation_models_pytorch==0.5.1.dev0) (1.5.2)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.24->segmentation_models_pytorch==0.5.1.dev0) (4.13.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.24->segmentation_models_pytorch==0.5.1.dev0) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.24->segmentation_models_pytorch==0.5.1.dev0) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.24->segmentation_models_pytorch==0.5.1.dev0) (3.11)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub>=0.24->segmentation_models_pytorch==0.5.1.dev0) (0.16.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1.11->segmentation_models_pytorch==0.5.1.dev0) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1.11->segmentation_models_pytorch==0.5.1.dev0) (3.0.3)
# Requirement already satisfied: click>=8.2.1 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub>=0.24->segmentation_models_pytorch==0.5.1.dev0) (8.3.2)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub>=0.24->segmentation_models_pytorch==0.5.1.dev0) (1.5.4)
# Requirement already satisfied: rich>=12.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub>=0.24->segmentation_models_pytorch==0.5.1.dev0) (13.9.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub>=0.24->segmentation_models_pytorch==0.5.1.dev0) (0.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer->huggingface-hub>=0.24->segmentation_models_pytorch==0.5.1.dev0) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer->huggingface-hub>=0.24->segmentation_models_pytorch==0.5.1.dev0) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer->huggingface-hub>=0.24->segmentation_models_pytorch==0.5.1.dev0) (0.1.2)
# Building wheels for collected packages: segmentation_models_pytorch
#   Building wheel for segmentation_models_pytorch (pyproject.toml) ... done
#   Created wheel for segmentation_models_pytorch: filename=segmentation_models_pytorch-0.5.1.dev0-py3-none-any.whl size=157855 sha256=ac5839aaeb948541d30993cbf2d5bdacfc73724261907d2f0333e7b96653908a
#   Stored in directory: /tmp/pip-ephem-wheel-cache-hftn3f_z/wheels/ef/38/4b/267c9bdb27c85ebaa11e9ec77c9059cf2c166ceee760f24429
# Successfully built segmentation_models_pytorch
# Installing collected packages: segmentation_models_pytorch
# Successfully installed segmentation_models_pytorch-0.5.1.dev0
# Collecting pytorch_lightning
#   Downloading pytorch_lightning-2.6.1-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (4.67.3)
# Collecting ipympl
#   Downloading ipympl-0.10.0-py3-none-any.whl.metadata (9.4 kB)
# Requirement already satisfied: torch>=2.1.0 in /usr/local/lib/python3.12/dist-packages (from pytorch_lightning) (2.10.0+cu128)
# Requirement already satisfied: PyYAML>5.4 in /usr/local/lib/python3.12/dist-packages (from pytorch_lightning) (6.0.3)
# Requirement already satisfied: fsspec>=2022.5.0 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]>=2022.5.0->pytorch_lightning) (2025.3.0)
# Collecting torchmetrics>0.7.0 (from pytorch_lightning)
#   Downloading torchmetrics-1.9.0-py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: packaging>=23.0 in /usr/local/lib/python3.12/dist-packages (from pytorch_lightning) (26.0)
# Requirement already satisfied: typing-extensions>4.5.0 in /usr/local/lib/python3.12/dist-packages (from pytorch_lightning) (4.15.0)
# Collecting lightning-utilities>=0.10.0 (from pytorch_lightning)
#   Downloading lightning_utilities-0.15.3-py3-none-any.whl.metadata (5.5 kB)
# Requirement already satisfied: ipython<10 in /usr/local/lib/python3.12/dist-packages (from ipympl) (7.34.0)
# Requirement already satisfied: ipywidgets<9,>=7.6.0 in /usr/local/lib/python3.12/dist-packages (from ipympl) (7.7.1)
# Requirement already satisfied: matplotlib<4,>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from ipympl) (3.10.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from ipympl) (2.0.2)
# Requirement already satisfied: pillow in /usr/local/lib/python3.12/dist-packages (from ipympl) (11.3.0)
# Requirement already satisfied: traitlets<6 in /usr/local/lib/python3.12/dist-packages (from ipympl) (5.7.1)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]>=2022.5.0->pytorch_lightning) (3.13.5)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.12/dist-packages (from ipython<10->ipympl) (75.2.0)
# Collecting jedi>=0.16 (from ipython<10->ipympl)
#   Downloading jedi-0.19.2-py2.py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: decorator in /usr/local/lib/python3.12/dist-packages (from ipython<10->ipympl) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.12/dist-packages (from ipython<10->ipympl) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from ipython<10->ipympl) (3.0.52)
# Requirement already satisfied: pygments in /usr/local/lib/python3.12/dist-packages (from ipython<10->ipympl) (2.20.0)
# Requirement already satisfied: backcall in /usr/local/lib/python3.12/dist-packages (from ipython<10->ipympl) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.12/dist-packages (from ipython<10->ipympl) (0.2.1)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.12/dist-packages (from ipython<10->ipympl) (4.9.0)
# Requirement already satisfied: ipykernel>=4.5.1 in /usr/local/lib/python3.12/dist-packages (from ipywidgets<9,>=7.6.0->ipympl) (6.17.1)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /usr/local/lib/python3.12/dist-packages (from ipywidgets<9,>=7.6.0->ipympl) (0.2.0)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.12/dist-packages (from ipywidgets<9,>=7.6.0->ipympl) (3.6.10)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from ipywidgets<9,>=7.6.0->ipympl) (3.0.16)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib<4,>=3.5.0->ipympl) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib<4,>=3.5.0->ipympl) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib<4,>=3.5.0->ipympl) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib<4,>=3.5.0->ipympl) (1.5.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib<4,>=3.5.0->ipympl) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib<4,>=3.5.0->ipympl) (2.9.0.post0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->pytorch_lightning) (3.25.2)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->pytorch_lightning) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->pytorch_lightning) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->pytorch_lightning) (3.1.6)
# Requirement already satisfied: cuda-bindings==12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->pytorch_lightning) (12.9.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->pytorch_lightning) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->pytorch_lightning) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->pytorch_lightning) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->pytorch_lightning) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->pytorch_lightning) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->pytorch_lightning) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->pytorch_lightning) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->pytorch_lightning) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->pytorch_lightning) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->pytorch_lightning) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->pytorch_lightning) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->pytorch_lightning) (3.4.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->pytorch_lightning) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->pytorch_lightning) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->pytorch_lightning) (1.13.1.3)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->pytorch_lightning) (3.6.0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings==12.9.4->torch>=2.1.0->pytorch_lightning) (1.5.2)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning) (1.23.0)
# Requirement already satisfied: debugpy>=1.0 in /usr/local/lib/python3.12/dist-packages (from ipykernel>=4.5.1->ipywidgets<9,>=7.6.0->ipympl) (1.8.15)
# Requirement already satisfied: jupyter-client>=6.1.12 in /usr/local/lib/python3.12/dist-packages (from ipykernel>=4.5.1->ipywidgets<9,>=7.6.0->ipympl) (7.4.9)
# Requirement already satisfied: nest-asyncio in /usr/local/lib/python3.12/dist-packages (from ipykernel>=4.5.1->ipywidgets<9,>=7.6.0->ipympl) (1.6.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from ipykernel>=4.5.1->ipywidgets<9,>=7.6.0->ipympl) (5.9.5)
# Requirement already satisfied: pyzmq>=17 in /usr/local/lib/python3.12/dist-packages (from ipykernel>=4.5.1->ipywidgets<9,>=7.6.0->ipympl) (26.2.1)
# Requirement already satisfied: tornado>=6.1 in /usr/local/lib/python3.12/dist-packages (from ipykernel>=4.5.1->ipywidgets<9,>=7.6.0->ipympl) (6.5.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.12/dist-packages (from jedi>=0.16->ipython<10->ipympl) (0.8.6)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.12/dist-packages (from pexpect>4.3->ipython<10->ipympl) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.12/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython<10->ipympl) (0.6.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib<4,>=3.5.0->ipympl) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=2.1.0->pytorch_lightning) (1.3.0)
# Requirement already satisfied: notebook>=4.4.1 in /usr/local/lib/python3.12/dist-packages (from widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl) (6.5.7)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=2.1.0->pytorch_lightning) (3.0.3)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.12/dist-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets<9,>=7.6.0->ipympl) (0.4)
# Requirement already satisfied: jupyter-core>=4.9.2 in /usr/local/lib/python3.12/dist-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets<9,>=7.6.0->ipympl) (5.9.1)
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.12/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl) (25.1.0)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.12/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl) (5.10.4)
# Requirement already satisfied: nbconvert>=5 in /usr/local/lib/python3.12/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl) (7.17.1)
# Requirement already satisfied: Send2Trash>=1.8.0 in /usr/local/lib/python3.12/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl) (2.1.0)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.12/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl) (0.18.1)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.12/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl) (0.25.0)
# Requirement already satisfied: nbclassic>=0.4.7 in /usr/local/lib/python3.12/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl) (1.3.3)
# Requirement already satisfied: idna>=2.0 in /usr/local/lib/python3.12/dist-packages (from yarl<2.0,>=1.17.0->aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning) (3.11)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.12/dist-packages (from jupyter-core>=4.9.2->jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets<9,>=7.6.0->ipympl) (4.9.6)
# Requirement already satisfied: notebook-shim>=0.2.3 in /usr/local/lib/python3.12/dist-packages (from nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl) (0.2.4)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.12/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl) (4.13.5)
# Requirement already satisfied: bleach!=5.0.0 in /usr/local/lib/python3.12/dist-packages (from bleach[css]!=5.0.0->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl) (6.3.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.12/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.12/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in /usr/local/lib/python3.12/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl) (3.2.0)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.12/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl) (0.10.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.12/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl) (1.5.1)
# Requirement already satisfied: fastjsonschema>=2.15 in /usr/local/lib/python3.12/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl) (2.21.2)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.12/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl) (4.26.0)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.12/dist-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl) (25.1.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.12/dist-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from bleach[css]!=5.0.0->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl) (1.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl) (0.30.0)
# Requirement already satisfied: jupyter-server<3,>=1.8 in /usr/local/lib/python3.12/dist-packages (from notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl) (2.14.0)
# Requirement already satisfied: cffi>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl) (2.0.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl) (2.8.3)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl) (3.0)
# Requirement already satisfied: anyio>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl) (4.13.0)
# Requirement already satisfied: jupyter-events>=0.9.0 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl) (0.12.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl) (0.5.4)
# Requirement already satisfied: overrides>=5.0 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl) (7.7.0)
# Requirement already satisfied: websocket-client>=1.7 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl) (1.9.0)
# Requirement already satisfied: python-json-logger>=2.0.4 in /usr/local/lib/python3.12/dist-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl) (4.1.0)
# Requirement already satisfied: rfc3339-validator in /usr/local/lib/python3.12/dist-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /usr/local/lib/python3.12/dist-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl) (0.1.1)
# Requirement already satisfied: fqdn in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl) (1.5.1)
# Requirement already satisfied: isoduration in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl) (3.1.1)
# Requirement already satisfied: rfc3987-syntax>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl) (1.1.0)
# Requirement already satisfied: uri-template in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl) (25.10.0)
# Requirement already satisfied: lark>=1.2.2 in /usr/local/lib/python3.12/dist-packages (from rfc3987-syntax>=1.1.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl) (1.3.1)
# Requirement already satisfied: arrow>=0.15.0 in /usr/local/lib/python3.12/dist-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl) (1.4.0)
# Requirement already satisfied: tzdata in /usr/local/lib/python3.12/dist-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl) (2026.1)
# Downloading pytorch_lightning-2.6.1-py3-none-any.whl (857 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 857.3/857.3 kB 64.7 MB/s eta 0:00:00
# Downloading ipympl-0.10.0-py3-none-any.whl (519 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 519.0/519.0 kB 49.1 MB/s eta 0:00:00
# Downloading lightning_utilities-0.15.3-py3-none-any.whl (31 kB)
# Downloading torchmetrics-1.9.0-py3-none-any.whl (983 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 983.4/983.4 kB 71.8 MB/s eta 0:00:00
# Downloading jedi-0.19.2-py2.py3-none-any.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 93.3 MB/s eta 0:00:00
# Installing collected packages: lightning-utilities, jedi, torchmetrics, pytorch_lightning, ipympl
# Successfully installed ipympl-0.10.0 jedi-0.19.2 lightning-utilities-0.15.3 pytorch_lightning-2.6.1 torchmetrics-1.9.0

# %%
# Set up monitoring and enable matplotlib notebook interactivity
# %matplotlib inline
import tensorboard
# %load_ext tensorboard

# %% [markdown]
# ## 0. Loading required libraries

# %%
import segmentation_models_pytorch as smp
import matplotlib.pyplot as plt
import pytorch_lightning as pl
import albumentations as A
import numpy as np
# import pydicom
import torch
import os
from utils import getFiles
from os.path import join
import pickle
## These are the structures defined in the FLARE data
structure_names = ['Body', 'Brainstem', 'Mandible', 'Parotids', 'Spinalcord']
## See if we're in colab...
if IN_COLAB:
    datapath = "/content/HnN_data/"
else:
    datapath = "/home/ed/autoseg_workshop_2023/HnN_data/"  ## <---- You will need to change this if running locally

# %% [markdown]
# ## 0. Download the New Model

# %% [markdown]
# Don't worry we've done the hard work to remove the aggresive manner in the way the model needs to be downloaded and we do this programmaticly as you have done in the previous parts.

# %%
if IN_COLAB:
  # !wget https://github.com/Christie-Scientific-Computing/HSST_Workshop/raw/refs/heads/main/setup/HnN_new_model.ckpt -O /content/HnN_new_model.ckpt
else:
  # !wget https://github.com/Christie-Scientific-Computing/HSST_Workshop/raw/refs/heads/main/setup/HnN_new_model.ckptt -O ./HnN_new_model.ckpt
# Out:
# --2026-04-16 10:00:53--  https://github.com/Christie-Scientific-Computing/HSST_Workshop/raw/refs/heads/main/setup/HnN_new_model.ckpt
# Resolving github.com (github.com)... 20.205.243.166
# Connecting to github.com (github.com)|20.205.243.166|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/Christie-Scientific-Computing/HSST_Workshop/refs/heads/main/setup/HnN_new_model.ckpt [following]
# --2026-04-16 10:00:53--  https://raw.githubusercontent.com/Christie-Scientific-Computing/HSST_Workshop/refs/heads/main/setup/HnN_new_model.ckpt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 52260689 (50M) [application/octet-stream]
# Saving to: ‘/content/HnN_new_model.ckpt’
#
# /content/HnN_new_mo 100%[===================>]  49.84M  --.-KB/s    in 0.1s
#
# 2026-04-16 10:00:57 (452 MB/s) - ‘/content/HnN_new_model.ckpt’ saved [52260689/52260689]

# %% [markdown]
# ## 1. Load the HN data

# %%
# Get the test data
test_datapath = join(datapath, "test")
fnames = sorted(getFiles(join(test_datapath, 'ims')))
test_ct_slices = np.zeros((len(fnames), 192, 192), dtype=np.float32)
test_mask_slices = np.zeros((len(fnames), 192, 192), dtype=np.float32)

for fdx, fname in enumerate(fnames):
    test_ct_slices[fdx] = np.load(join(test_datapath, "ims", fname))
    test_mask_slices[fdx] = np.load(join(test_datapath, "masks", fname))

for fdx, fname in enumerate(fnames):
    pass
# load pixel spacing
with open(join(test_datapath, "spacings.pkl"), "rb") as f:
    pass

print(test_ct_slices.shape)
print(test_mask_slices.shape)
# Out:
# (217, 192, 192)
# (217, 192, 192)

# %%
## Define the class that will wrap te pytorch model up for ptl
class LightningFPN(pl.LightningModule):
  def __init__(self):
    super().__init__()
    ## Create the pytorch model
    self.model = smp.FPN("resnet18", in_channels=1, classes=len(structure_names)+1, encoder_weights='imagenet')

    ## Construct a loss function, this is DSC, configured for multiple classes, and ignoring the background
    self.loss_fcn = smp.losses.DiceLoss("multiclass", from_logits=True)

    ## Specify which optimiser to use here
    self.optimizer = torch.optim.Adam

  def forward(self, x):
    return self.model(x)

  def configure_optimizers(self):
    optimizer = self.optimizer(self.parameters(), lr=1e-4)## May need to handle other kwargs here!
    return {"optimizer": optimizer, "reduce_on_plateau":True}
    ## Note - we are reducing the learning rate when the validation loss plateaus for a while - this should improve the model

  def training_step(self, batch, batch_idx):
    # Separate batch into input, mask and spacing (although we ignore the spacing)
    img, msk, _ = batch
    # Pass the input through the model and get a prediction (msk_hat)
    msk_hat = self(img)
    # Calculate average prediction error on this batch
    loss = self.loss_fcn(msk_hat, msk.long())
    # Log the error
    self.log("loss", loss)
    return loss

  def validation_step(self, batch, batch_idx):
    # Identical to the training step
    img, msk, _ = batch
    msk_hat = self(img)
    val_loss = self.loss_fcn(msk_hat, msk.long())
    self.log("val_loss", val_loss)
    return val_loss

## Now we can wrap the prebuilt model up inside a pytorch lightning module:
pl_model = LightningFPN()

## Done!
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:93: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/156 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/46.8M [00:00<?, ?B/s]

# %%
import torch.utils.data as data

# Define a simple dataset/loader to fetch a sample for visualization
class SimpleDataset(data.Dataset):
    def __init__(self, images, masks):
        self.images = images
        self.masks = masks
    def __len__(self):
        return len(self.images)
    def __getitem__(self, idx):
        # Return image (add channel dim), mask, and a dummy spacing
        return torch.from_numpy(self.images[idx]).unsqueeze(0), torch.from_numpy(self.masks[idx]), torch.tensor([1.0, 1.0])

val_dataset = SimpleDataset(test_ct_slices, test_mask_slices)
val_dataloader = data.DataLoader(val_dataset, batch_size=1, shuffle=False)

# FIX: Call load_from_checkpoint on the CLASS, not an instance
model_path = os.path.join("/content/", "HnN_new_model.ckpt")
model_trained = LightningFPN.load_from_checkpoint(model_path)
model_trained.eval()

# Get a sample
in_image, in_mask, in_spacing = next(iter(val_dataloader))

# take the first example from the batch
all_gt = in_mask[0].numpy().copy().astype(float)

# Predict
with torch.no_grad():
    logits = model_trained(in_image)
    probs = torch.nn.functional.softmax(logits, dim=1)[0].numpy()

test_mask = np.argmax(probs, axis=0).astype(float)

# For visualization: make background (0) nan
all_gt[all_gt == 0.0] = np.nan
test_mask_vis = test_mask.copy()
test_mask_vis[test_mask_vis == 0.0] = np.nan

## Show the results
fig = plt.figure(figsize=(10,10))
ax_gt = fig.add_subplot(121)
ax_gt.set_title("Ground Truth")
ax_cnn = fig.add_subplot(122)
ax_cnn.set_title("CNN contour")

ax_gt.imshow(in_image[0].squeeze(), cmap='Greys_r')
ax_gt.imshow(all_gt, alpha=0.75, cmap='viridis', vmin=1, vmax=5)
ax_gt.invert_yaxis()

ax_cnn.imshow(in_image[0].squeeze(), cmap='Greys_r')
ax_cnn.imshow(test_mask_vis, alpha=0.75, cmap='viridis', vmin=1, vmax=5)
ax_cnn.invert_yaxis()
plt.show()

# %% [markdown]
# ## 1. Running Evals

# %%
from utils import compute_dice_coefficient, compute_surface_distances, compute_average_surface_distance, compute_robust_hausdorff

in_image, in_mask, in_spacing = next(iter(val_dataloader))
in_spacing = in_spacing[0].numpy()

distance_measures = {name : {} for name in structure_names[1:]}
organ_labels = [1, 2, 3, 4] # labels to match structure_names[1:]

for name, organ_label in zip(structure_names[1:], organ_labels):

    cnn_prediction = test_mask == organ_label
    gt = all_gt == organ_label

    if np.sum(gt) == 0:
        print(f"Skipping {name} as there are no ground truth labels in this slice")
        continue

    if np.sum(cnn_prediction) == 0:
        print(f"Skipping {name} as there are no CNN predictions in this slice")
        continue

    surface_distances = compute_surface_distances(gt, cnn_prediction, spacing_mm=in_spacing)

    distance_measures[name]['msd'] = compute_average_surface_distance(surface_distances)
    distance_measures[name]["HD95"] = compute_robust_hausdorff(surface_distances, 95)
    distance_measures[name]["DSC"] = compute_dice_coefficient(gt, cnn_prediction)

    print(f"{name}\n\tMSD: {distance_measures[name]['msd']:.3f} mm\n\tHD95: {distance_measures[name]['HD95']:.3f} mm\n\tDSC: {distance_measures[name]['DSC']:.3f}\n")
# Out:
# Brainstem
# 	MSD: 17.899 mm
# 	HD95: 50.000 mm
# 	DSC: 0.806
#
# Skipping Mandible as there are no CNN predictions in this slice
# Parotids
# 	MSD: 57.288 mm
# 	HD95: 98.005 mm
# 	DSC: 0.000
#
# Spinalcord
# 	MSD: 105.127 mm
# 	HD95: 194.258 mm
# 	DSC: 0.000

# %%
MSDs = {name : [] for name in structure_names[1:]}
HD95s = {name : [] for name in structure_names[1:]}
DSCs = {name : [] for name in structure_names[1:]}
failures = {name : 0 for name in structure_names[1:]}

# Correct labels for Brainstem, Mandible, Parotids, Spinalcord
organ_labels = [1, 2, 3, 4]

print("Evaluating all test slices...")

for in_image, in_mask, in_spacing in val_dataloader:
    # Move to device and predict
    in_image = in_image.to(model_trained.device)
    with torch.no_grad():
        logits = model_trained(in_image)
        probs = torch.nn.functional.softmax(logits, dim=1)[0].cpu().numpy()

    test_mask = np.argmax(probs, axis=0).astype(float)
    all_gt = in_mask[0].numpy().astype(float)

    # Fix: Get the spacing for this slice as a numpy array [dx, dy]
    sp = in_spacing[0].numpy() if torch.is_tensor(in_spacing) else 1.0

    for name, organ_label in zip(structure_names[1:], organ_labels):
        cnn_prediction = test_mask == organ_label
        gt = all_gt == organ_label

        if np.sum(gt) == 0:
            continue

        if np.sum(cnn_prediction) == 0:
            failures[name] += 1
            continue

        surface_distances = compute_surface_distances(gt, cnn_prediction, spacing_mm=sp)
        MSDs[name].append(compute_average_surface_distance(surface_distances))
        HD95s[name].append(compute_robust_hausdorff(surface_distances, 95))
        DSCs[name].append(compute_dice_coefficient(gt, cnn_prediction))

print("\nMean MSDs")
for name in structure_names[1:]:
    val = np.mean(MSDs[name]) if MSDs[name] else 0.0
    print(f"\t{name}: {val:.3f} mm")

print("\nMean HD95s")
for name in structure_names[1:]:
    val = np.mean(HD95s[name]) if HD95s[name] else 0.0
    print(f"\t{name}: {val:.3f} mm")

print("\nMean DSCs")
for name in structure_names[1:]:
    val = np.mean(DSCs[name]) if DSCs[name] else 0.0
    print(f"\t{name}: {val:.3f}")

print("\nFailures (GT present but no prediction)")
for name in structure_names[1:]:
    print(f"\t{name}: {failures[name]}")
# Out:
# Evaluating all test slices...
#
# Mean MSDs
# 	Brainstem: 26.259 mm
# 	Mandible: 0.000 mm
# 	Parotids: 57.802 mm
# 	Spinalcord: 102.460 mm
#
# Mean HD95s
# 	Brainstem: 56.375 mm
# 	Mandible: 0.000 mm
# 	Parotids: 100.007 mm
# 	Spinalcord: 193.720 mm
#
# Mean DSCs
# 	Brainstem: 0.693
# 	Mandible: 0.000
# 	Parotids: 0.001
# 	Spinalcord: 0.000
#
# Failures (GT present but no prediction)
# 	Brainstem: 0
# 	Mandible: 89
# 	Parotids: 56
# 	Spinalcord: 166

# %% [markdown]
# Why has the performance degraded? Do you have any ideas before we start our investigation? If so feel free to list them below:

# %% [markdown]
# ## 2. Investigating performance change

# %% [markdown]
# To investigate the change in performance you may want to think about:
# - Is the validation dataset still representative?
# - How has the training data changed?
# - What does the manufacturer say?

# %% [markdown]
# ## Vendor response
#
# **From:** [info@SuperContouringExpress.com](mailto:info@SuperContouringExpress.com)
#
# **Subject:** Re: Issues in local performance
#
# **Date:** 29th April 2026
#
# ---
#
# Hi valuable customer,
#
# Thank you for reaching out. Normally a response would take between 1-2 weeks, but it just so happens I had my laptop open when this email came in, you are welcome.
#
# That performance change does not align with the fantastic new model we have released. The new model is trained using X more patients, so it is now super robust. There are no changes to the model architecture as that was perfect already. Talking to the team we wonder if this is an issue with your patients? Could you ask them if they can align better with the our dataset?
#
# > ⚠️ **Please note** that the current version of the H+N AI contouring model will **still** be removed by the 8th June 2026.
#
# You are most welcome,
#
# **The Super Contouring Express Team**

# %% [markdown]
# ## Database analysis

# %% [markdown]
# ## 3. Result Discussions

# %% [markdown]
# *If you have finished before others, please use this time to reflect on what you might do in this situation.*
#
# At this stage, we will discuss how you would handle this exact scenario. The degraded performance has made the AI essentially unusable, yet the previous, stable version is being sunset imminently. While Super Contouring Express is fictional, aspects of this scenario is not. How do you think the following concepts impact clinical safety, utility, and department resilience?
#
# Topics to think about:
# - Vendor lock-in and forced obsolescence
# - Cloud-First vs. Local Change Control
# - Continuous commissioning from rapid AI model updates.
# - Downstream Pipeline Breakages
# - The Black Box Defense
# - "Skill Fade" and Contingency Planning
# - Clinical Risk Management
